# %% [markdown]
# # Análisis Exploratorio de Datos (EDA)  🔎
# ## Los Simpson – Episodios y Personajes 🍩
#
# El objetivo de este notebook es realizar un análisis exploratorio de los datasets correspondientes a los episodios y personajes de *Los Simpson*.
#
# Antes de proceder a la visualización en Tableau, se lleva a cabo una fase de revisión y preparación de los datos con el fin de:
#
# - Comprender la estructura y dimensiones de los datasets.
# - Detectar posibles inconsistencias, valores nulos o duplicados.
# - Validar tipos de datos.
# - Generar variables derivadas que faciliten el análisis posterior.
#
# Este proceso permite garantizar la calidad del dato y construir una base sólida para el desarrollo de dashboards analíticos en Tableau.

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df_characters=pd.read_csv('../01_data/raw/simpson_characters.csv')
df_episodes=pd.read_csv('../01_data/raw/simpson_episodes.csv')

# %%
# Función auxiliar para realizar un análisis exploratorio inicial (EDA).
# Resume información clave del dataset: primeras filas, estructura, estadísticos,
# cardinalidad, valores nulos y duplicados.
# Permite estandarizar el análisis y aplicarlo de forma consistente a distintos datasets.

def eda(df, name="Dataset"):
    """
    Realiza un EDA rápido del dataframe.
    
    Parameters
    ----------
    df : pd.DataFrame
        DataFrame a analizar.
    name : str, default="Dataset"
        Nombre del dataset para identificar la salida.
        
    """
    print(f"🔍 PRIMER VISTAZO A LOS DATOS — {name}")
    display(df.head())
    display(df.tail())
             
    print("\n🧱 ESTRUCTURA DEL DATAFRAME")
    print(f"📐 Dimensiones (filas, columnas): {df.shape}")
    
    print("\n🧠 Información general:")
    df.info()

    # -------------------------
    print("\n📉 ESTADÍSTICAS DESCRIPTIVAS")
    print("\n📈 Variables numéricas:")
    display(df.describe().T)

    # Estadística para categóricas solo si existen
    cat_cols = df.select_dtypes(include=["object", "category"]).columns
    print("\n🔤 Variables categóricas:")
    if len(cat_cols) > 0:
        display(df[cat_cols].describe().T)
    else:
        print("No hay columnas categóricas (object/category) en este dataset.")

    # -------------------------
    # Cardinalidad (número de valores únicos por columna)
    # Útil para detectar variables identificadoras, columnas constantes y posibles errores de tipado.
    # dropna=False cuenta NaN como un valor adicional para evaluar su impacto.
    print("\n🔢 CARDINALIDAD")
    cardinalidad = df.nunique(dropna=False).sort_values(ascending=False)
    display(pd.DataFrame(cardinalidad, columns=["Valores únicos"]))

    # -------------------------
    print("\n🚫 VALORES NULOS")
    nulos = df.isnull().sum()
    nulos_pct = (nulos / len(df) * 100).round(2)

    nulos_df = pd.DataFrame({
        "Nulos": nulos,
        "% Nulos": nulos_pct
    }).sort_values("% Nulos", ascending=False)

    display(nulos_df)

    # -------------------------
    print("\n📎 DUPLICADOS")
    dup_count = df.duplicated().sum()
    print(f"Duplicados: {dup_count}")
    if dup_count > 0:
        display(df[df.duplicated()])

# %%
eda(df_characters, "Simpsons Characters")
eda(df_episodes, "Simpsons Episodes")
# Out:
# 🔍 PRIMER VISTAZO A LOS DATOS — Simpsons Characters
#    id              name   normalized_name gender
# 0   7          Children          children    NaN
# 1  12  Mechanical Santa  mechanical santa    NaN
# 2  13        Tattoo Man        tattoo man    NaN
# 3  16  DOCTOR ZITSOFSKY  doctor zitsofsky    NaN
# 4  20          Students          students    NaN
#         id             name  normalized_name gender
# 6717  5222   Ron Rabinowitz   ron rabinowitz      m
# 6718  5728   Martha Stewart   martha stewart      f
# 6719  1770  Officer Goodman  officer goodman      m
# 6720  1634     Evan Conover     evan conover      m
# 6721  1868    Agent Johnson    agent johnson      m
# 🧱 ESTRUCTURA DEL DATAFRAME
# 📐 Dimensiones (filas, columnas): (6722, 4)
#
# 🧠 Información general:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6722 entries, 0 to 6721
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
# ...

# %% [markdown]
# ## Conclusiones del EDA y decisiones de preparación
#
# Tras la realización del análisis exploratorio se observó lo siguiente:
#
# - El dataset de episodios presenta una estructura consistente y prácticamente sin valores nulos, detectándose únicamente un registro con audiencia faltante (0,13% del total).
# - La variable de fecha (`original_air_date`) se encontraba en formato texto (object), por lo que es necesario convertirla a formato datetime para permitir un análisis temporal adecuado.
# - No se identificaron duplicados ni inconsistencias significativas en las variables de rating.
# - En el dataset de personajes, la variable `gender` presenta un elevado porcentaje de valores nulos, lo que limita su utilidad analítica.
#
# En base a estas observaciones, se realizaron las siguientes acciones antes de trasladar los datos a Tableau:
#
# - Eliminación del único registro con audiencia nula, debido a su impacto estadístico irrelevante.
# - Conversión de la fecha de emisión a formato datetime.
# - Creación de variables derivadas (`year`, `rating_diff` y `us_viewers_absolute` como audiencia convertida de millones a valor absoluto) para facilitar el análisis posterior.
# - Eliminación de la variable `gender` del dataset de personajes por su baja calidad informativa.
#
# Tras estas transformaciones, los datasets quedan limpios, estructurados y preparados para su explotación analítica y visualización.

# %%
# Eliminación de la columna 'gender' del dataset de personajes, ya que no es relevante para el análisis y puede introducir sesgos.
df_characters.drop(columns=['gender'], inplace=True)

# %%
# Eliminación del único registro nulo en la columna 'us_viewers_in_millions' del dataset de episodios.
df_episodes.dropna(subset=['us_viewers_in_millions'], inplace=True)

# %%
# Creación de una nueva columna 'year' para extraer el año de emisión de cada episodio a partir de la columna 'original_air_date'.
df_episodes["year"] = pd.to_datetime(df_episodes["original_air_date"]).dt.year

# %%
# Creación de una nueva columna 'ratting_diff' para calcular la diferencia entre las calificaciones de IMDb y TMDb, lo que permitirá analizar posibles discrepancias entre ambas fuentes.
df_episodes["rating_diff"] = (df_episodes["imdb_rating"] - df_episodes["tmdb_rating"]).round(2)

# %%
# Creación de una nueva columna 'us_viewers_absolute' para convertir la cantidad de espectadores en millones a espectadores absolutos.
df_episodes["us_viewers_absolute"] = df_episodes["us_viewers_in_millions"] * 1_000_000

# %%
# Comprobación de que no existen valores nulos o vacíos en las columnas relevantes.
df_characters.isnull().sum()
# Out:
# id                 0
# name               0
# normalized_name    0
# dtype: int64

# %%
df_episodes.isnull().sum()
# Out:
# id                        0
# title                     0
# description               0
# original_air_date         0
# production_code           0
# directed_by               0
# written_by                0
# season                    0
# number_in_season          0
# number_in_series          0
# us_viewers_in_millions    0
# imdb_rating               0
# tmdb_rating               0
# tmdb_vote_count           0
# year                      0
# rating_diff               0
# us_viewers_absolute       0
# dtype: int64

# %%
# Guardado de los datasets limpios en la carpeta de datos procesados para su uso en análisis posteriores.
df_characters.to_csv("../01_data/processed/simpson_characters_clean.csv", index=False)
df_episodes.to_csv("../01_data/processed/simpson_episodes_clean.csv", index=False)
